# %%
from sklearn.manifold import TSNE
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score, davies_bouldin_score
#from itables import init_notebook_mode
#init_notebook_mode(all_interactive=True)


sns.set()

url = "https://github.com/renatoquiliche/Insurance-Mathematics-Economics-ADR/blob/main/Databases/insurance.csv?raw=true"

data_insurance = pd.read_csv(url)

# %%
data_insurance.columns.values.tolist()
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']

# %% [markdown]
# # Data pre-processing

# %%
categorical = pd.get_dummies(data_insurance[["sex","smoker"]]) 
numerical = data_insurance[["age","bmi","children", "charges"]]

scaler = RobustScaler()

#Escalamos la data numerica a la escala de la binaria
numerical_data_scaled = pd.DataFrame(scaler.fit_transform(numerical), columns=["age","bmi","children", "charges"])

#Unimos los dos tipos de data
final_data_scaled = pd.concat([numerical_data_scaled, categorical], axis=1)

# %% [markdown]
# The regions were removed, localization variables add noise to the clusterin algorithm. The results will be further tested against the localization categories

# %%
tsne = TSNE(n_components=2, perplexity=50, n_iter=1000, early_exaggeration=12,
            init='pca', learning_rate='auto', method='barnes_hut', n_jobs=-1)
vecs_list_tsne = tsne.fit_transform(final_data_scaled)

print("Training error: ", tsne.kl_divergence_)
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\manifold\_t_sne.py:991: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# Training error:  0.5133529901504517

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=vecs_list_tsne[:,0], y=vecs_list_tsne[:,1], size=data_insurance['children'], sizes=(0, 300))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Fit a clustering algortihm

# %% [markdown]
# ## Hierarchical clustering, linkage single

# %%
from sklearn import metrics

wcss = []
sil = []
db = []
ch = []
components = pd.DataFrame(vecs_list_tsne, columns=['tsne1', 'tsne2'])

for i in range(2,20):
    HClustering = AgglomerativeClustering(n_clusters= i, linkage='single')
    HClustering.fit(components)
    #wcss.append(kmeans.inertia_)
    sil.append(silhouette_score(components, HClustering.labels_))
    db.append(davies_bouldin_score(components, HClustering.labels_))
    ch.append(metrics.calinski_harabasz_score(components, HClustering.labels_))

# %%
# SC Graph
plt.plot(range(2,20), sil, color="steelblue")
#plt.title('The Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('Silhouette Coefficient')
plt.axvline(3, color="indianred") # vertical
#plt.savefig(path_fig+"\Elbowmethod.png")
plt.show()

# %%
# DB Graph
plt.plot(range(2,20), db, color="steelblue")
plt.title('The Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('Davies-Bouldin Index')
plt.axvline(3, color="indianred") # vertical
#plt.savefig(path_fig+"\Elbowmethod.png")
plt.show()

# %%
from sklearn.metrics import pairwise_distances

# DB Graph
plt.plot(range(2,20), ch, color="steelblue")
plt.title('The Elbow Method')
plt.xlabel('No of clusters')
plt.ylabel('Calinski-Harabasz Index')
plt.axvline(3, color="indianred") # vertical
#plt.savefig(path_fig+"\Elbowmethod.png")
plt.show()

# %%
# Cluster label estimation

clusters = 3

exec(f"HClustering{clusters} = AgglomerativeClustering(n_clusters={clusters}, linkage='single')")
exec(f"HClustering{clusters}.fit(components)")

# Concat labels to original dataset
exec(f"data_final = pd.concat([data_insurance, pd.Series(HClustering{clusters}.labels_, name='HCluster{clusters}')], axis=1)")

# %%
from sklearn.cluster import DBSCAN

DBSCAN = DBSCAN(eps=3.8, min_samples=10)
DBSCAN.fit(components)

data_final["DBSC"] = DBSCAN.labels_

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=vecs_list_tsne[:,0],y=vecs_list_tsne[:,1],
                hue=data_final["DBSC"],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Cluster visualization

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=vecs_list_tsne[:,0],y=vecs_list_tsne[:,1],
                hue=data_final[f'HCluster{clusters}'],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
from math import inf
data_final["BMI"] = pd.cut(data_final.bmi,bins=[0, 30, inf], labels=["Non-obesity(BMI<30)", "Obesity(BMI>30)"])

data_final["smoker"] = data_final["smoker"].astype("category") 

data_final["sex"] = data_final["sex"].astype("category")

# %%
import warnings
warnings.filterwarnings("ignore")

input_simulation = data_final[["charges", "sex", "BMI", "smoker"]]

input_simulation["smoker"] = input_simulation["smoker"].str.replace('no','Non-smoker')
input_simulation["smoker"] = input_simulation["smoker"].str.replace('yes','Smoker')

input_simulation["sex"] = input_simulation["sex"].str.replace('male','Male')
input_simulation["sex"] = input_simulation["sex"].str.replace('female','Female', case=False)

input_simulation["CategoricalClustering"] = input_simulation["BMI"].astype(str) + " & " + input_simulation["smoker"].astype(str) + " & " + input_simulation["sex"].astype(str)

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=vecs_list_tsne[:,0],y=vecs_list_tsne[:,1],
                hue=input_simulation['CategoricalClustering'],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
from sklearn.tree import DecisionTreeClassifier

categorical = pd.get_dummies(input_simulation[["BMI", "sex", "smoker"]], drop_first=True)
numerical = data_insurance[["charges", "children", "age"]]
DecisionTree = DecisionTreeClassifier(max_leaf_nodes=None, criterion="entropy", random_state=0)

x = pd.concat([numerical, categorical], axis=1)
y = data_final["DBSC"]

DecisionTree.fit(x, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
from dtreeviz.trees import dtreeviz # remember to load the package

viz = dtreeviz(DecisionTree, x, y,
                target_name="target",
                feature_names=x.columns.values)

viz

# %%
pd.DataFrame(x.columns.values)

DecisionTree.feature_importances_
# Out:
# array([0.06006104, 0.        , 0.        , 0.04985061, 0.49144354,
#        0.39864481])

# %%
feature_importances = pd.concat([pd.DataFrame(x.columns.values, columns=["Feature"]), 
           pd.DataFrame(DecisionTree.feature_importances_, columns=["Importance"])], axis=1)

sns.barplot(data=feature_importances.sort_values(by=["Importance"], ascending=False)
            , y="Feature", x="Importance")
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=data_insurance["age"],y=data_insurance["charges"],
                hue=data_final["DBSC"],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=data_insurance["bmi"],y=data_insurance["charges"],
                hue=data_final["DBSC"],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=data_insurance["children"],y=data_insurance["charges"],
                hue=data_final["DBSC"],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(9,8))
sns.scatterplot(x=data_insurance["bmi"],y=data_insurance["charges"],
                hue=data_final["sex"],alpha=1, palette='tab10',
                   sizes=(0, 400), size=data_insurance['charges'])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
input_simulation
# Out:
#           charges     sex                  BMI      smoker  \
# 0     16884.92400  Female  Non-obesity(BMI<30)      Smoker
# 1      1725.55230    Male      Obesity(BMI>30)  Non-smoker
# 2      4449.46200    Male      Obesity(BMI>30)  Non-smoker
# 3     21984.47061    Male  Non-obesity(BMI<30)  Non-smoker
# 4      3866.85520    Male  Non-obesity(BMI<30)  Non-smoker
# ...           ...     ...                  ...         ...
# 1333  10600.54830    Male      Obesity(BMI>30)  Non-smoker
# 1334   2205.98080  Female      Obesity(BMI>30)  Non-smoker
# 1335   1629.83350  Female      Obesity(BMI>30)  Non-smoker
# 1336   2007.94500  Female  Non-obesity(BMI<30)  Non-smoker
# 1337  29141.36030  Female  Non-obesity(BMI<30)      Smoker
#
#                           CategoricalClustering
# 0         Non-obesity(BMI<30) & Smoker & Female
# 1           Obesity(BMI>30) & Non-smoker & Male
# 2           Obesity(BMI>30) & Non-smoker & Male
# 3       Non-obesity(BMI<30) & Non-smoker & Male
# 4       Non-obesity(BMI<30) & Non-smoker & Male
# ...                                         ...
# 1333        Obesity(BMI>30) & Non-smoker & Male
# 1334      Obesity(BMI>30) & Non-smoker & Female
# 1335      Obesity(BMI>30) & Non-smoker & Female
# 1336  Non-obesity(BMI<30) & Non-smoker & Female
# 1337      Non-obesity(BMI<30) & Smoker & Female
#
# [1338 rows x 5 columns]

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('charges ~ C(CategoricalClustering)', data=input_simulation).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                 sum_sq      df           F  PR(>F)
# C(CategoricalClustering)  1.501205e+11     7.0  620.688176     0.0
# Residual                  4.595368e+10  1330.0         NaN     NaN

# %%
from bioinfokit.analys import stat
# perform multiple pairwise comparison (Tukey's HSD)
# unequal sample size data, tukey_hsd uses Tukey-Kramer test
res = stat()
res.tukey_hsd(df=input_simulation, res_var='charges', xfac_var='CategoricalClustering'
              , anova_model='charges ~ C(CategoricalClustering)')


display(res.tukey_summary)

print("(p-value < 0.05) rejects null hypothesis and indicates statistically significant differences")
# Out:
#                                        group1  \
# 0       Non-obesity(BMI<30) & Smoker & Female
# 1       Non-obesity(BMI<30) & Smoker & Female
# 2       Non-obesity(BMI<30) & Smoker & Female
# 3       Non-obesity(BMI<30) & Smoker & Female
# 4       Non-obesity(BMI<30) & Smoker & Female
# 5       Non-obesity(BMI<30) & Smoker & Female
# 6       Non-obesity(BMI<30) & Smoker & Female
# 7         Obesity(BMI>30) & Non-smoker & Male
# 8         Obesity(BMI>30) & Non-smoker & Male
# 9         Obesity(BMI>30) & Non-smoker & Male
# 10        Obesity(BMI>30) & Non-smoker & Male
# 11        Obesity(BMI>30) & Non-smoker & Male
# 12        Obesity(BMI>30) & Non-smoker & Male
# 13    Non-obesity(BMI<30) & Non-smoker & Male
# 14    Non-obesity(BMI<30) & Non-smoker & Male
# 15    Non-obesity(BMI<30) & Non-smoker & Male
# 16    Non-obesity(BMI<30) & Non-smoker & Male
# 17    Non-obesity(BMI<30) & Non-smoker & Male
# 18  Non-obesity(BMI<30) & Non-smoker & Female
# 19  Non-obesity(BMI<30) & Non-smoker & Female
# 20  Non-obesity(BMI<30) & Non-smoker & Female
# 21  Non-obesity(BMI<30) & Non-smoker & Female
# 22      Obesity(BMI>30) & Non-smoker & Female
# 23      Obesity(BMI>30) & Non-smoker & Female
# 24      Obesity(BMI>30) & Non-smoker & Female
# 25            Obesity(BMI>30) & Smoker & Male
# 26            Obesity(BMI>30) & Smoker & Male
# 27          Obesity(BMI>30) & Smoker & Female
#
#                                        group2          Diff         Lower  \
# 0         Obesity(BMI>30) & Non-smoker & Male  12584.164705  10095.105598
# 1     Non-obesity(BMI<30) & Non-smoker & Male  13450.176653  10921.932407
# 2   Non-obesity(BMI<30) & Non-smoker & Female  12791.371250  10290.229860
# 3       Obesity(BMI>30) & Non-smoker & Female  11853.262168   9366.643145
# 4             Obesity(BMI>30) & Smoker & Male  20267.922458  17349.849179
# 5           Obesity(BMI>30) & Smoker & Female  21250.584242  17907.313815
# 6         Non-obesity(BMI<30) & Smoker & Male    580.511779  -2551.032329
# 7     Non-obesity(BMI<30) & Non-smoker & Male    866.011949   -708.511833
# 8   Non-obesity(BMI<30) & Non-smoker & Female    207.206545  -1323.418955
# 9       Obesity(BMI>30) & Non-smoker & Female    730.902537   -775.875593
# 10            Obesity(BMI>30) & Smoker & Male  32852.087162  30706.799809
# 11          Obesity(BMI>30) & Smoker & Female  33834.748946  31139.463561
# 12        Non-obesity(BMI<30) & Smoker & Male  13164.676484  10736.987322
# 13  Non-obesity(BMI<30) & Non-smoker & Female    658.805403   -934.749790
# 14      Obesity(BMI>30) & Non-smoker & Female   1596.914485     26.250910
# 15            Obesity(BMI>30) & Smoker & Male  33718.099111  31527.468708
# 16          Obesity(BMI>30) & Smoker & Female  34700.760895  31969.247204
# 17        Non-obesity(BMI<30) & Smoker & Male  14030.688432  11562.839490
# 18      Obesity(BMI>30) & Non-smoker & Female    938.109082   -588.545218
# 19            Obesity(BMI>30) & Smoker & Male  33059.293708  30899.999646
# 20          Obesity(BMI>30) & Smoker & Female  34041.955492  31335.508313
# 21        Non-obesity(BMI<30) & Smoker & Male  13371.883029  10931.807685
# 22            Obesity(BMI>30) & Smoker & Male  32121.184626  29978.728849
# 23          Obesity(BMI>30) & Smoker & Female  33103.846410  30410.814245
# 24        Non-obesity(BMI<30) & Smoker & Male  12433.773947  10008.586615
# 25          Obesity(BMI>30) & Smoker & Female    982.661784  -2113.190237
# 26        Non-obesity(BMI<30) & Smoker & Male  19687.410679  16821.505744
# 27        Non-obesity(BMI<30) & Smoker & Male  20670.072463  17372.237328
#
#            Upper    q-value   p-value
# 0   15073.223811  21.705231  0.001000
# 1   15978.420900  22.839373  0.001000
# 2   15292.512640  21.956043  0.001000
# 3   14339.881191  20.464628  0.001000
# 4   23185.995737  29.818669  0.001000
# 5   24593.854668  27.288181  0.001000
# 6    3712.055887   0.795844  0.900000
# 7    2440.535730   2.361293  0.681196
# 8    1737.832045   0.581179  0.900000
# 9    2237.680666   2.082502  0.798844
# 10  34997.374516  65.743484  0.001000
# 11  36530.034332  53.893132  0.001000
# 12  15592.365646  23.280502  0.001000
# 13   2252.360597   1.774865  0.900000
# 14   3167.578060   4.364894  0.043107
# 15  35908.729514  66.079872  0.001000
# 16  37432.274586  54.539460  0.001000
# 17  16498.537374  24.408193  0.001000
# 18   2464.763381   2.638079  0.564395
# 19  35218.587770  65.728996  0.001000
# 20  36748.402670  53.999553  0.001000
# 21  15811.958373  23.526892  0.001000
# 22  34263.640403  64.365761  0.001000
# 23  35796.878575  52.773043  0.001000
# 24  14858.961279  22.010651  0.001000
# 25   4078.513805   1.362696  0.900000
# 26  22553.315613  29.491852  0.001000
# 27  23967.907598  26.908425  0.001000
# (p-value < 0.05) rejects null hypothesis and indicates statistically significant differences

# %%
res.tukey_summary.sort_values(by=["q-value"], ascending=False)
# Out:
#                                        group1  \
# 15    Non-obesity(BMI<30) & Non-smoker & Male
# 10        Obesity(BMI>30) & Non-smoker & Male
# 19  Non-obesity(BMI<30) & Non-smoker & Female
# 22      Obesity(BMI>30) & Non-smoker & Female
# 16    Non-obesity(BMI<30) & Non-smoker & Male
# 20  Non-obesity(BMI<30) & Non-smoker & Female
# 11        Obesity(BMI>30) & Non-smoker & Male
# 23      Obesity(BMI>30) & Non-smoker & Female
# 4       Non-obesity(BMI<30) & Smoker & Female
# 26            Obesity(BMI>30) & Smoker & Male
# 5       Non-obesity(BMI<30) & Smoker & Female
# 27          Obesity(BMI>30) & Smoker & Female
# 17    Non-obesity(BMI<30) & Non-smoker & Male
# 21  Non-obesity(BMI<30) & Non-smoker & Female
# 12        Obesity(BMI>30) & Non-smoker & Male
# 1       Non-obesity(BMI<30) & Smoker & Female
# 24      Obesity(BMI>30) & Non-smoker & Female
# 2       Non-obesity(BMI<30) & Smoker & Female
# 0       Non-obesity(BMI<30) & Smoker & Female
# 3       Non-obesity(BMI<30) & Smoker & Female
# 14    Non-obesity(BMI<30) & Non-smoker & Male
# 18  Non-obesity(BMI<30) & Non-smoker & Female
# 7         Obesity(BMI>30) & Non-smoker & Male
# 9         Obesity(BMI>30) & Non-smoker & Male
# 13    Non-obesity(BMI<30) & Non-smoker & Male
# 25            Obesity(BMI>30) & Smoker & Male
# 6       Non-obesity(BMI<30) & Smoker & Female
# 8         Obesity(BMI>30) & Non-smoker & Male
#
#                                        group2          Diff         Lower  \
# 15            Obesity(BMI>30) & Smoker & Male  33718.099111  31527.468708
# 10            Obesity(BMI>30) & Smoker & Male  32852.087162  30706.799809
# 19            Obesity(BMI>30) & Smoker & Male  33059.293708  30899.999646
# 22            Obesity(BMI>30) & Smoker & Male  32121.184626  29978.728849
# 16          Obesity(BMI>30) & Smoker & Female  34700.760895  31969.247204
# 20          Obesity(BMI>30) & Smoker & Female  34041.955492  31335.508313
# 11          Obesity(BMI>30) & Smoker & Female  33834.748946  31139.463561
# 23          Obesity(BMI>30) & Smoker & Female  33103.846410  30410.814245
# 4             Obesity(BMI>30) & Smoker & Male  20267.922458  17349.849179
# 26        Non-obesity(BMI<30) & Smoker & Male  19687.410679  16821.505744
# 5           Obesity(BMI>30) & Smoker & Female  21250.584242  17907.313815
# 27        Non-obesity(BMI<30) & Smoker & Male  20670.072463  17372.237328
# 17        Non-obesity(BMI<30) & Smoker & Male  14030.688432  11562.839490
# 21        Non-obesity(BMI<30) & Smoker & Male  13371.883029  10931.807685
# 12        Non-obesity(BMI<30) & Smoker & Male  13164.676484  10736.987322
# 1     Non-obesity(BMI<30) & Non-smoker & Male  13450.176653  10921.932407
# 24        Non-obesity(BMI<30) & Smoker & Male  12433.773947  10008.586615
# 2   Non-obesity(BMI<30) & Non-smoker & Female  12791.371250  10290.229860
# 0         Obesity(BMI>30) & Non-smoker & Male  12584.164705  10095.105598
# 3       Obesity(BMI>30) & Non-smoker & Female  11853.262168   9366.643145
# 14      Obesity(BMI>30) & Non-smoker & Female   1596.914485     26.250910
# 18      Obesity(BMI>30) & Non-smoker & Female    938.109082   -588.545218
# 7     Non-obesity(BMI<30) & Non-smoker & Male    866.011949   -708.511833
# 9       Obesity(BMI>30) & Non-smoker & Female    730.902537   -775.875593
# 13  Non-obesity(BMI<30) & Non-smoker & Female    658.805403   -934.749790
# 25          Obesity(BMI>30) & Smoker & Female    982.661784  -2113.190237
# 6         Non-obesity(BMI<30) & Smoker & Male    580.511779  -2551.032329
# 8   Non-obesity(BMI<30) & Non-smoker & Female    207.206545  -1323.418955
#
#            Upper    q-value   p-value
# 15  35908.729514  66.079872  0.001000
# 10  34997.374516  65.743484  0.001000
# 19  35218.587770  65.728996  0.001000
# 22  34263.640403  64.365761  0.001000
# 16  37432.274586  54.539460  0.001000
# 20  36748.402670  53.999553  0.001000
# 11  36530.034332  53.893132  0.001000
# 23  35796.878575  52.773043  0.001000
# 4   23185.995737  29.818669  0.001000
# 26  22553.315613  29.491852  0.001000
# 5   24593.854668  27.288181  0.001000
# 27  23967.907598  26.908425  0.001000
# 17  16498.537374  24.408193  0.001000
# 21  15811.958373  23.526892  0.001000
# 12  15592.365646  23.280502  0.001000
# 1   15978.420900  22.839373  0.001000
# 24  14858.961279  22.010651  0.001000
# 2   15292.512640  21.956043  0.001000
# 0   15073.223811  21.705231  0.001000
# 3   14339.881191  20.464628  0.001000
# 14   3167.578060   4.364894  0.043107
# 18   2464.763381   2.638079  0.564395
# 7    2440.535730   2.361293  0.681196
# 9    2237.680666   2.082502  0.798844
# 13   2252.360597   1.774865  0.900000
# 25   4078.513805   1.362696  0.900000
# 6    3712.055887   0.795844  0.900000
# 8    1737.832045   0.581179  0.900000

# %%
input_simulation["DBSC"] = data_final["DBSC"]

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('charges ~ C(DBSC)', data=input_simulation).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                 sum_sq      df            F  PR(>F)
# C(DBSC)   1.507172e+11     4.0  1107.358216     0.0
# Residual  4.535705e+10  1333.0          NaN     NaN

# %%
res = stat()
res.tukey_hsd(df=input_simulation, res_var='charges', xfac_var='DBSC'
              , anova_model='charges ~ C(DBSC)')

res.tukey_summary.sort_values(by=["q-value"], ascending=False)
# Out:
#    group1  group2          Diff         Lower         Upper    q-value  \
# 5       1       3  33467.232534  31981.829293  34952.635774  87.034772
# 7       2       3  32792.139966  31315.829988  34268.449944  85.804401
# 9       3       4  20851.349796  18454.450605  23248.248987  33.604835
# 2       0       3  20484.400820  18087.501629  22881.300011  33.013446
# 0       0       1  12982.831714  10856.612080  15109.051348  23.587324
# 6       1       4  12615.882738  10489.663104  14742.102371  22.920647
# 1       0       2  12307.739146  10187.862193  14427.616098  22.427713
# 8       2       4  11940.790169   9820.913217  14060.667122  21.759042
# 4       1       2    675.092568   -302.238158   1652.423295   2.668328
# 3       0       4    366.948976  -2471.979145   3205.877097   0.499308
#
#     p-value
# 5  0.001000
# 7  0.001000
# 9  0.001000
# 2  0.001000
# 0  0.001000
# 6  0.001000
# 1  0.001000
# 8  0.001000
# 4  0.324779
# 3  0.900000

# %% [markdown]
# Fusionar clusters 1 y 2, 0 y 4

# %% [markdown]
# Este algorithm nos lleva a las mismas conclusiones de arriba:
#
# - The variable smoker defines natural clusters in the data (perfect Rand-score and Jaccard Index versus Hierarchical partition)
# - The variable obesity generates a good partition into clusters when individuals smoke, proposed partition:
#     - **Cluster 0:** Non-smoker
#     - **Cluster 1:** Smoker + Non-obesity
#     - **Cluster 2:** Smoker + Obesity
#
# - The Non-smoker are the problem, they have non-linear complex patterns that divide them into natural clusters
# - Another option: train a decision tree to make K-means clustering interpretable in terms of variables in original feature space
#
# Sin embargo, esta conclusion es solo univariada, se tendria que hacer un analisis multivariado para hombres y mujeres, y evaluar si dentro de estos grupos hay diferencias significativas
